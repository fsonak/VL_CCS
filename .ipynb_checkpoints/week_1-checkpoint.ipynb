# %% [markdown]
# **Week 1: Velocity Distributions**
#
# Jannek Schaffert, Frédéric Sonak
#
# **Background:**
# Regardless of initial conditions, velocity distributions in multi-particle systems with collisions between particles tend to converge to a Maxwell-Boltzmann distribution. To observe this effect, we will create our own simulation of a multi-particle system consisting of hard spheres within a 2D box. ChatGPT was used to assist with the markdown.
#
# **Task I - Implementation**
# In this first section, we will outline how we developed an algorithm to simulate hard spheres within a box. Key features of our algorithm include:
# - Elastic collisions between hard spheres
# - Multi-particle interactions
# - Periodic boundary conditions for the box
#
# All code will be provided in easy-to-use functions that will later be called in Task II.

# %% [markdown]
# Importing all external libraries used in this code

# %%
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

import copy
import numpy as np
import scipy as scy

# %% [markdown]
# Creating a particle class:

# %%
class Particle:
    def __init__(self, r, x, y, vx, vy):
        self.r = r
        self.x = x
        self.y = y
        self.vx = vx
        self.vy = vy
        
    def __repr__(self):
        return str("This is a particle at %0.2f, %0.2f with v=%0.2f,%0.2f" % (self.x,self.y,self.vx,self.vy))

# %% [markdown]
# Defining the parameters used in the simulation later on

# %%
# defining the box
box_size_x = 20
box_size_y = 20

box = [box_size_x,box_size_y]

# %%
# defining the number of particles and their corresponding radius
number_of_particles = 50
radius = 0.5

# %%
# Initialising the velocities
baseline_velocity = 0.5 # same velocity magnitude for all particles 

# random direction of the velocity in 2D for each particle
vel = np.ones(number_of_particles) * baseline_velocity
angles = np.random.uniform(0,2 * np.pi, number_of_particles)

# %%
# Initialising the positions
# random positions for each particle
x_rand = np.random.randint(1,box[0]-1,number_of_particles)
y_rand = np.random.randint(1,box[1]-1,number_of_particles)

# %%
# Setting up the particle:
# Each particle gets assigned a position (x,y) and a velocity (v_x, v_y).
particles = []
for i in range(number_of_particles):
    particles.append(Particle(radius,x_rand[i],y_rand[i],np.sin(angles[i]) * vel[i],np.cos(angles[i]) * vel[i]))

# %%
# Defining number of simulation steps
steps = 1000

# %% [markdown]
# Initialise trajectory:

# %%
data_traj = np.zeros((number_of_particles,4,steps))
data_traj.shape
# Out:
# (50, 4, 100)

# %% [markdown]
# Euler integrator scheme:
# Define time integrator for numerical, stepwise solution of equation of motion with a discrete time step $dt$:

# %%
# define time step dt for simulation
dt = 1

def move(p,dt):
    p.x = p.x + p.vx * dt
    p.y = p.y + p.vy * dt
    return p

# %% [markdown]
# Define a move function to move particles for each time step.

# %%
def move_unbound(p,dt):
    p.x = np.mod(p.x + p.vx * dt, box_size_x)
    p.y = np.mod(p.y + p.vy * dt, box_size_y)
    return p

# %% [markdown]
# Define box reflection:

# %%
def reflect(p):
    if (p.x + p.r) >= box[0]:
        p.vx = p.vx * (-1)
    if (p.x) <= p.r:
        p.vx = p.vx * (-1)
    if (p.y + p.r) >= box[1]:
        p.vy = p.vy * (-1)
    if (p.y) <= p.r:
        p.vy = p.vy * (-1)
    return p

# %% [markdown]
# Define a function that calculates new velocities for two particles (with the same mass) colliding with two different velocities in 2D. The formulas can be found here:
#  https://hermann-baum.de/elastischer_stoss/, 24.10.2024.

# %%
def collide_simple(particles):
    for i in range(len(particles)): # looping through all particles
        for j in range(len(particles)):
            if i < j:
                distance = np.sqrt(np.abs(particles[i].x-particles[j].x)**2+np.abs(particles[i].y-particles[j].y)**2)
                if distance<(particles[i].r+particles[j].r):
                    # calculate angle between x-axis and line between particles
                    phi = np.arctan((particles[j].y - particles[i].y)/(particles[j].x - particles[i].x))
                    # change the velocities
                    particles[i].vx = ( particles[i].vx*np.sin(phi)-particles[i].vy*np.cos(phi))*np.sin(phi)+(particles[j].vx*np.cos(phi)+particles[j].vy*np.sin(phi))*np.cos(phi)
                    particles[i].vy = (-particles[i].vx*np.sin(phi)+particles[i].vy*np.cos(phi))*np.cos(phi)+(particles[j].vx*np.cos(phi)+particles[j].vy*np.sin(phi))*np.sin(phi)
                    particles[j].vx = ( particles[j].vx*np.sin(phi)-particles[j].vy*np.cos(phi))*np.sin(phi)+(particles[i].vx*np.cos(phi)+particles[i].vy*np.sin(phi))*np.cos(phi)
                    particles[j].vy = (-particles[j].vx*np.sin(phi)+particles[j].vy*np.cos(phi))*np.cos(phi)+(particles[i].vx*np.cos(phi)+particles[i].vy*np.sin(phi))*np.sin(phi)
                    #print(particles[i],particles[j],'collided with a distance of ', distance)

# %% [markdown]
# The following algorithm operates by checking pairwise collisions between particles. When a collision is detected—defined by any overlap between two particles—the particles are moved back in time so that they are just touching. New velocities are then calculated by temporarily rotating the coordinate system to simplify calculations. Afterward, time is advanced forward again, using the updated velocities, so that each particle progresses equally within one calculation step.
#
# If a particle is near the box boundary (close to a zero position on either axis), the algorithm also checks for any particles located on the opposite side of the box to account for periodic boundary conditions.
#
# ChatGPT was used to assist in debugging this implementation.

# %%
def calculate_distance(particle_1, particle_2):
    distance = np.sqrt(np.abs(particle_1.x - particle_2.x)**2+np.abs(particle_1.y - particle_2.y)**2)
    return distance


def collision(particles,data_traj,step, dt,i,j):
    distance_vector = np.array([particles[j].x-particles[i].x,particles[j].y-particles[i].y])# von i nach j
    distance = np.sqrt(np.abs(distance_vector[0])**2+np.abs(distance_vector[1])**2)
    R = particles[i].r+particles[j].r
    if distance<R:
        print(particles[i],particles[j],'collided with a distance of ', distance)
        # angle between x-axis and line between particles
        phi = np.arctan((particles[j].y - particles[i].y)/(particles[j].x - particles[i].x))
        
        # in time
        # defining re-used variables
        v_x = particles[i].vx-particles[j].vx
        v_y = particles[i].vy-particles[j].vy

        r_x = particles[j].x-particles[i].x
        r_y = particles[j].y-particles[i].y

        #calculating the time needed to travel back in two steps:
        sqrt = 2*np.sqrt((r_x*v_x+r_y*v_y)**2-(v_x**2+v_y**2)*(r_x**2+r_y**2-R**2))
        
        delta_t = -1*(-2*(r_x*v_x+r_y*v_y) + sqrt)/(2*(v_x**2+v_y**2))
        
        #solving the quadratic equation results in two solutions (one positive and one negative), we want the negative solution, for backwards time-travel
        if delta_t > 0:
            delta_t = -1*(-2*(r_x*v_x+r_y*v_y) - sqrt)/(2*(v_x**2+v_y**2))

        # rewind time to just outside of the collision
        particles[i].x = particles[i].x + particles[i].vx*delta_t
        particles[i].y = particles[i].y + particles[i].vy*delta_t
        particles[j].x = particles[j].x + particles[j].vx*delta_t
        particles[j].y = particles[j].y + particles[j].vy*delta_t

        # change the velocities

        # only calculate once, used multiple times
        sin_phi = np.sin(phi)
        cos_phi = np.cos(phi)

        # Get the velocities of particles i and j as variables
        v1x, v1y = particles[i].vx, particles[i].vy
        v2x, v2y = particles[j].vx, particles[j].vy

        # Calculate the updated velocities using the provided formulas: https://hermann-baum.de/elastischer_stoss/
        # the tangental part stays the same, the normal part changes. This is done in transformed coordinates and then transformed directly back
        new_v1x = (v1x * sin_phi - v1y * cos_phi) * sin_phi + (v2x * cos_phi + v2y * sin_phi) * cos_phi
        new_v1y = (-v1x * sin_phi + v1y * cos_phi) * cos_phi + (v2x * cos_phi + v2y * sin_phi) * sin_phi
        new_v2x = (v2x * sin_phi - v2y * cos_phi) * sin_phi + (v1x * cos_phi + v1y * sin_phi) * cos_phi
        new_v2y = (-v2x * sin_phi + v2y * cos_phi) * cos_phi + (v1x * cos_phi + v1y * sin_phi) * sin_phi

        # Update the particles' velocities
        particles[i].vx, particles[i].vy = new_v1x, new_v1y
        particles[j].vx, particles[j].vy = new_v2x, new_v2y

        # finish this time_step, that was rewound previously and open the boundaries again with np.mod
        particles[i].x = np.mod(particles[i].x - particles[i].vx*delta_t,box_size_x)
        particles[i].y = np.mod(particles[i].y - particles[i].vy*delta_t,box_size_y)
        particles[j].x = np.mod(particles[j].x - particles[j].vx*delta_t,box_size_x)
        particles[j].y = np.mod(particles[j].y - particles[j].vy*delta_t,box_size_y)
        # debugging
        distance = np.sqrt(np.abs(particles[i].x-particles[j].x)**2+np.abs(particles[i].y-particles[j].y)**2)
        #print(particles[i],particles[j],'collided with a distance of ', distance)

def collide_border(particles,data_traj,step, dt,i,x):
    # set particle to the opposite box
    if x:
        pos_x = particles[i].x+box_size_x
    else:
        pos_y = particles[i].y+box_size_y
    # check for collisions
    for j in range(len(particles)):
        if i < j:
            collision(particles,data_traj,step, dt, i, j)
            

def collide_boundary(particles,data_traj,step, dt):
    #run through all pairwise possible interactions and check collisions
    for i in range(len(particles)):
        for j in range(len(particles)):
            if i < j:
                collision(particles,data_traj,step, dt, i, j)
        # account for edge cases
        if particles[i].x<particles[i].r:
            collide_border(particles,data_traj,step, dt,i,True)
        if particles[i].y<particles[i].r:
            collide_border(particles,data_traj,step, dt,i,False)

# %% [markdown]
# **Task II - Carrying out the simulation**
# In the following the above functions will be implemented to run a simulation.
#
# The actual integration happens here. Everything is saved to the predefined data_traj-array.

# %%
for i in range(steps):
    for j in range(number_of_particles):
        move_unbound(particles[j],1)
        collide_boundary(particles,data_traj,i,dt)    
        for j in range(number_of_particles):
            data_traj[j,:,i] = [particles[j].x, particles[j].y, particles[j].vx, particles[j].vy]
# Out:
# This is a particle at 16.00, 4.00 with v=-0.50,-0.04 This is a particle at 16.00, 4.00 with v=0.48,0.13 collided with a distance of  0.0
# This is a particle at 5.00, 11.00 with v=-0.50,0.04 This is a particle at 5.00, 11.00 with v=-0.37,0.34 collided with a distance of  0.0
# This is a particle at 14.00, 13.00 with v=-0.27,-0.42 This is a particle at 14.00, 13.00 with v=0.10,-0.49 collided with a distance of  0.0
# This is a particle at 1.00, 14.00 with v=0.45,-0.21 This is a particle at 1.00, 14.00 with v=0.45,0.22 collided with a distance of  0.0
# This is a particle at 12.00, 9.00 with v=0.27,-0.42 This is a particle at 12.00, 9.00 with v=0.17,-0.47 collided with a distance of  0.0
# This is a particle at 3.00, 10.00 with v=-0.24,-0.44 This is a particle at 3.00, 10.00 with v=-0.14,0.48 collided with a distance of  0.0
# This is a particle at 15.06, 8.50 with v=0.06,-0.50 This is a particle at 15.00, 8.00 with v=0.43,-0.26 collided with a distance of  0.5070257961858403
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.783480989002695
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793784
# This is a particle at 10.50, 6.06 with v=-0.50,0.06 This is a particle at 10.00, 6.00 with v=0.12,0.49 collided with a distance of  0.5063649982684979
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026974
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793815
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026989
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.834038110579383
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422543
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310859
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422431
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310812
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422465
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310779
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.625394229842232
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310795
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422382
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310888
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422351
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310888
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422382
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.784383411631084
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.625394229842227
# This is a particle at 15.53, 7.16 with v=-0.47,0.16 This is a particle at 14.96, 7.62 with v=0.40,-0.54 collided with a distance of  0.7350820200992083
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.784383411631095
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422254
# This is a particle at 15.12, 8.86 with v=0.10,-0.23
# <ipython-input-14-a59e34d0734f>:13: RuntimeWarning: invalid value encountered in long_scalars
#   phi = np.arctan((particles[j].y - particles[i].y)/(particles[j].x - particles[i].x))
#  This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310984
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 17.74, 13.57 with v=-0.26,-0.43 This is a particle at 18.00, 13.00 with v=0.07,-0.49 collided with a distance of  0.6253942298422381
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 18.03, 12.93 with v=-0.18,-0.61 This is a particle at 17.71, 13.64 with v=-0.00,-0.32 collided with a distance of  0.7843834116310999
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 13.50, 7.96 with v=0.50,-0.04 This is a particle at 14.28, 7.96 with v=-0.47,0.17 collided with a distance of  0.783640340892325
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.10, 8.88 with v=0.09,-0.22 This is a particle at 14.74, 9.57 with v=-0.26,-0.43 collided with a distance of  0.7834809890026958
# This is a particle at 15.12, 8.86 with v=0.10,-0.23 This is a particle at 14.73, 9.60 with v=-0.27,-0.41 collided with a distance of  0.8340381105793799
# This is a particle at 15.20, 8.66 with v=0.09,-0.22 This is a particle at 14.50, 7.95 with v=0.50,0.15 collided with a distance of  0.9963821888098224
# This is a particle at 15.20, 8.67 with v=0.48,0.18 This is a particle at 14.48, 9.15 with v=-0.26,-0.43 collided with a distance of  0.8694972333312457
# This is a particle at 15.00, 8.80 with v=0.24,0.33 This is a particle at 14.50, 7.95 with v=0.11,-0.24 collided with a distance of  0.9873631821969215
# This is a particle at 14.68, 9.01 with v=-0.03,-0.58 This is a particle at 15.41, 9.50 with v=0.40,0.24 collided with a distance of  0.8838686898316259
# This is a particle at 17.49, 13.14 with v=-0.26,-0.43 This is a particle at 18.07, 12.51 with v=0.07,-0.49 collided with a distance of  0.8651869165121299
# This is a particle at 6.43, 14.90 with v=0.21,0.45 This is a particle at 7.08, 14.61 with v=-0.46,-0.19 collided with a distance of  0.7136526186167462
# This is a particle at 2.38, 13.55 with v=0.13,-0.48 This is a particle at 2.21, 12.98 with v=0.10,0.49 collided with a distance of  0.5965320539156994
# This is a particle at 14.04, 7.10 with v=-0.04,-0.15 This is a particle at 13.39, 6.43 with v=0.46,-0.19 collided with a distance of  0.9296888162995645
# This is a particle at 2.88, 12.00 with v=-0.37,-0.33 This is a particle at 2.09, 12.60 with v=-0.17,-0.39 collided with a distance of  0.9930589325598357
# This is a particle at 15.50, 2.08 with v=0.50,0.03 This is a particle at 16.20, 1.40 with v=-0.40,-0.30 collided with a distance of  0.9808184440933648
# This is a particle at 9.48, 13.22 with v=0.49,0.07 This is a particle at 10.01, 13.16 with v=-0.49,0.08 collided with a distance of  0.532757513402149
# This is a particle at 10.13, 2.49 with v=0.04,0.50 This is a particle at 10.78, 2.87 with v=-0.41,0.29 collided with a distance of  0.743958338670365
# This is a particle at 10.94, 3.94 with v=-0.35,-0.35 This is a particle at 11.00, 2.99 with v=0.02,0.54 collided with a distance of  0.9488220092235233
# This is a particle at 9.67, 15.89 with v=0.42,-0.28 This is a particle at 10.43, 15.46 with v=0.48,0.15 collided with a distance of  0.8789908137809654
# This is a particle at 14.27, 7.23 with v=0.19,0.08 This is a particle at 14.60, 6.43 with v=-0.35,0.36 collided with a distance of  0.8649227943567553
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141615
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587894
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141615
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587894
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141618
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587894
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141615
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587894
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141615
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.746032395058789
# This is a particle at 15.03, 2.54 with v=0.41,-0.29 This is a particle at 15.69, 2.41 with v=0.20,0.32 collided with a distance of  0.6680472682641527
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141613
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.746032395058789
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141613
# This is a particle at 17.84, 9.41 with v=0.65,-0.14 This is a particle at 18.13, 10.33 with v=-0.07,-0.63 collided with a distance of  0.9586046858784121
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.746032395058789
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141613
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 2.37, 3.09 with v=0.27,0.42 This is a particle at 2.99, 3.83 with v=0.50,-0.04 collided with a distance of  0.9639613404178566
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 15.74, 0.49 with v=-0.05,0.50 This is a particle at 16.01, 0.21 with v=-0.10,-0.59 collided with a distance of  0.3905989046250391
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 6.86, 8.01 with v=-0.54,0.41 This is a particle at 6.03, 8.28 with v=0.21,0.46 collided with a distance of  0.8751770497412766
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106384
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328599
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106384
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328606
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106392
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328606
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.962726630510641
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.44, 8.06 with v=-0.18,-0.23 collided with a distance of  0.7460323950587889
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328625
# This is a particle at 14.23, 7.86 with v=0.01,0.51 This is a particle at 13.36, 8.08 with v=-0.28,-0.21 collided with a distance of  0.8956913538141611
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106429
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.26, 7.83 with v=-0.18,-0.23 collided with a distance of  0.9037775566042568
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.984437811532863
# This is a particle at 14.06, 7.87 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.6969611456362098
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106429
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.26, 7.83 with v=-0.18,-0.23 collided with a distance of  0.9037775566042604
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328637
# This is a particle at 14.06, 7.87 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.6969611456362134
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106441
# This is a particle at 14.16, 7.87 with v=-0.09,0.53 This is a particle at 13.26, 7.83 with v=-0.18,-0.23 collided with a distance of  0.9037775566042586
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328637
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801255
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106422
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711305999898
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.984437811532863
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801306
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106417
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711305999907
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.984437811532863
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801232
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106423
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711305999932
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.984437811532863
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801296
# This is a particle at 13.82, 5.55 with v=0.24,-0.42 This is a particle at 14.48, 6.25 with v=-0.17,-0.07 collided with a distance of  0.9627266305106422
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000028
# This is a particle at 13.81, 5.54 with v=0.22,-0.44 This is a particle at 14.49, 6.25 with v=-0.16,-0.05 collided with a distance of  0.9844378115328625
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801314
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000034
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000009
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.736277022280127
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000009
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.736277022280127
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000041
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801259
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000098
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801296
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000091
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000053
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801277
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000098
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801277
# This is a particle at 10.60, 6.94 with v=0.10,0.49 This is a particle at 10.93, 7.85 with v=-0.47,-0.02 collided with a distance of  0.9673971119570168
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000117
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.736277022280132
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000123
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801307
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000053
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 7.58, 13.84 with v=-0.48,0.19 This is a particle at 6.82, 13.53 with v=-0.14,-0.34 collided with a distance of  0.8156846127727869
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 7.65, 13.87 with v=-0.37,0.23 This is a particle at 6.75, 13.50 with v=-0.25,-0.38 collided with a distance of  0.9803130487447859
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801289
# This is a particle at 7.58, 13.84 with v=-0.48,0.19 This is a particle at 6.82, 13.53 with v=-0.14,-0.34 collided with a distance of  0.8156846127727869
# This is a particle at 13.35, 7.83 with v=-0.52,0.18 This is a particle at 13.85, 8.40 with v=0.25,0.13 collided with a distance of  0.7618711306000059
# This is a particle at 7.65, 13.87 with v=-0.37,0.23 This is a particle at 6.75, 13.50 with v=-0.25,-0.38 collided with a distance of  0.9803130487447852
# This is a particle at 13.84, 8.39 with v=-0.22,0.53 This is a particle at 13.36, 7.84 with v=-0.05,-0.22 collided with a distance of  0.7362770222801277
# This is a particle at 2.63, 3.58 with v=0.14,0.26 This is a particle at 2.51, 4.39 with v=-0.25,-0.43 collided with a distance of  0.8235141599300436
# This is a particle at 18.06, 3.72 with v=0.39,-0.54 This is a particle at 17.46, 3.13 with v=0.51,0.26 collided with a distance of  0.8426475290159171
# This is a particle at 7.10, 14.03 with v=-0.48,0.19 This is a particle at 6.68, 13.19 with v=-0.14,-0.34 collided with a distance of  0.9324586145076385
# This is a particle at 6.85, 13.54 with v=-0.62,-0.10 This is a particle at 6.93, 13.68 with v=0.00,-0.05 collided with a distance of  0.16387751160321315
# This is a particle at 7.10, 14.03 with v=-0.48,0.19 This is a particle at 6.68, 13.19 with v=-0.14,-0.34 collided with a distance of  0.9324586145076389
# This is a particle at 6.85, 13.54 with v=-0.62,-0.10 This is a particle at 6.93, 13.68 with v=0.00,-0.05 collided with a distance of  0.16387751160321315
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226327
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938742
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226256
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938713
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226227
# This is a particle at 0.93, 4.73 with v=0.49,0.09 This is a particle at 1.81, 4.94 with v=-0.34,0.19 collided with a distance of  0.906500774629301
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938713
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226227
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938713
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226197
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938762
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226177
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938733
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226169
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938676
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226239
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938726
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226268
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938656
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226268
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938656
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226248
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938656
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226297
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938683
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226277
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938635
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226285
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938565
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226265
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938494
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226265
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938565
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226314
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938544
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226292
# This is a particle at 1.18, 5.58 with v=-0.09,-0.49 This is a particle at 1.91, 4.96 with v=0.42,0.37 collided with a distance of  0.9549192285250284
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938523
# This is a particle at 18.26, 19.01 with v=0.03,-0.50 This is a particle at 17.73, 19.75 with v=0.47,-0.04 collided with a distance of  0.9123056653226244
# This is a particle at 18.19, 19.10 with v=-0.04,-0.40 This is a particle at 17.80, 19.66 with v=0.54,-0.14 collided with a distance of  0.6846450126938551
# This is a particle at 19.80, 10.70 with v=-0.33,-0.27 This is a particle at 19.61, 9.97 with v=-0.49,0.11 collided with a distance of  0.7507890480800289
# This is a particle at 12.32, 0.56 with v=-0.62,-0.05 This is a particle at 11.45, 0.99 with v=0.08,-0.33 collided with a distance of  0.9659321243705211
# This is a particle at 0.30, 4.52 with v=-0.27,-0.09 This is a particle at 0.03, 5.42 with v=0.44,-0.79 collided with a distance of  0.9403500502040103
# This is a particle at 0.32, 4.46 with v=-0.02,-0.93 This is a particle at 0.94, 5.21 with v=-0.22,-0.39 collided with a distance of  0.9685809958259971
# This is a particle at 0.02, 5.48 with v=0.19,0.05 This is a particle at 0.60, 4.80 with v=-0.40,-0.61 collided with a distance of  0.8923565597956837
# This is a particle at 0.06, 5.42 with v=0.26,-0.03 This is a particle at 0.56, 4.85 with v=-0.47,-0.53 collided with a distance of  0.7570718089344389
# This is a particle at 0.66, 4.87 with v=0.17,-0.70 This is a particle at 0.02, 5.48 with v=0.19,0.05 collided with a distance of  0.8827897915468411
# This is a particle at 0.00, 5.49 with v=-0.19,-0.36 This is a particle at 0.60, 4.80 with v=-0.40,-0.61 collided with a distance of  0.9098517265693189
# This is a particle at 0.07, 5.42 with v=-0.16,-0.40 This is a particle at 0.67, 4.86 with v=0.55,-0.30 collided with a distance of  0.8229053106883131
# This is a particle at 0.66, 4.86 with v=0.17,-0.71 This is a particle at 0.54, 4.88 with v=-0.44,-0.57 collided with a distance of  0.1237060411203191
# This is a particle at 1.65, 4.74 with v=0.18,-0.65 This is a particle at 2.48, 5.21 with v=0.55,0.27 collided with a distance of  0.9521158703059609
# This is a particle at 18.82, 10.50 with v=0.14,0.03 This is a particle at 19.61, 10.97 with v=-0.24,0.04 collided with a distance of  0.9221823094059205
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079437
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310691
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.947752584907942
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310691
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079446
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079471
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079453
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310709
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079462
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310726
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079453
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079437
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079395
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079446
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310726
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079419
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310726
# This is a particle at 7.21, 4.12 with v=-0.39,0.25 This is a particle at 6.81, 4.56 with v=0.63,0.12 collided with a distance of  0.5932974300548113
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079419
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310726
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079437
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310744
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079471
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310717
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079411
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079429
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.98374904583107
# This is a particle at 18.75, 10.46 with v=-0.14,-0.13 This is a particle at 18.97, 9.54 with v=-0.57,-0.21 collided with a distance of  0.9477525849079463
# This is a particle at 18.75, 10.48 with v=-0.15,-0.11 This is a particle at 18.98, 9.52 with v=-0.56,-0.24 collided with a distance of  0.9837490458310735
# ...
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.23695439217742853
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.667841943151088
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.23695439217742853
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.667841943151088
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.2369543921774251
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.6678419431510677
# This is a particle at 19.29, 12.38 with v=0.40,0.26 This is a particle at 19.83, 12.36 with v=-0.29,-0.47 collided with a distance of  0.540373993502432
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.2369543921774364
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.667841943151081
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.23695439217743988
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.6678419431511012
# This is a particle at 16.83, 15.64 with v=0.38,-0.39 This is a particle at 17.74, 15.79 with v=-0.93,-0.04 collided with a distance of  0.9240509811715856
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 18.79, 13.82 with v=0.26,0.03 collided with a distance of  0.236954392177432
# This is a particle at 18.91, 14.00 with v=-0.26,0.38 This is a particle at 18.54, 13.45 with v=0.10,-0.21 collided with a distance of  0.6678419431511062
# This is a particle at 18.66, 13.63 with v=-0.42,0.14 This is a particle at 19.05, 13.85 with v=0.26,0.03 collided with a distance of  0.4523072164429679
# This is a particle at 18.66, 12.68 with v=-0.26,0.28 This is a particle at 18.16, 13.35 with v=-0.21,-0.24 collided with a distance of  0.8336221775496484
# This is a particle at 19.77, 17.63 with v=-0.30,0.12 This is a particle at 19.85, 17.03 with v=0.27,0.65 collided with a distance of  0.6020859017536578
# This is a particle at 2.88, 16.41 with v=-0.54,0.99 This is a particle at 3.42, 17.06 with v=0.18,-0.29 collided with a distance of  0.8454912870056867
# This is a particle at 10.31, 1.42 with v=0.17,0.02 This is a particle at 11.15, 1.21 with v=0.03,0.35 collided with a distance of  0.8759994605728638
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189758
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185478
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.746930348618549
# This is a particle at 19.37, 18.49 with v=-0.36,0.56 This is a particle at 19.84, 19.26 with v=0.24,-0.17 collided with a distance of  0.8932951612568076
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189758
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185478
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.746930348618549
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.87, 13.32 with v=0.06,0.47 collided with a distance of  0.7469303486185465
# This is a particle at 14.23, 13.87 with v=-0.84,-0.59 This is a particle at 14.94, 13.26 with v=0.25,0.31 collided with a distance of  0.9366800092189744
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171287
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.49193134048745957
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.630627508617134
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.4919313404874649
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171376
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.4919313404874702
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171429
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.4919313404874649
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171429
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.4919313404874649
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171393
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.49193134048746134
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171376
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.49193134048745957
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171376
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.49193134048746484
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171339
# This is a particle at 14.86, 13.79 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.4919313404874684
# This is a particle at 14.30, 13.80 with v=-0.65,-0.75 This is a particle at 14.93, 13.79 with v=0.06,0.47 collided with a distance of  0.6306275086171357
# This is a particle at 14.90, 13.03 with v=0.04,-0.76 This is a particle at 14.37, 13.80 with v=-0.63,0.49 collided with a distance of  0.9341328300025629
# This is a particle at 13.65, 8.55 with v=0.18,0.23 This is a particle at 14.42, 9.04 with v=-0.02,0.07 collided with a distance of  0.9062353362174114
# This is a particle at 0.89, 17.34 with v=0.33,0.20 This is a particle at 1.05, 17.49 with v=-0.88,0.58 collided with a distance of  0.21958689617702715
# This is a particle at 11.18, 17.15 with v=0.16,0.37 This is a particle at 11.12, 17.82 with v=0.72,-0.02 collided with a distance of  0.6808525320988326
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599742
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555541
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599739
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555543
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599738
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555541
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599736
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.913684330855554
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599736
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555539
# This is a particle at 19.78, 16.14 with v=0.05,0.40 This is a particle at 18.96, 16.44 with v=0.29,0.16 collided with a distance of  0.8761394270789935
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599735
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.913684330855554
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599735
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555539
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599734
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.913684330855554
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599735
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.913684330855554
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599736
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555543
# This is a particle at 14.92, 0.21 with v=0.56,-0.29 This is a particle at 14.28, 0.95 with v=0.24,-0.52 collided with a distance of  0.9737191439599738
# This is a particle at 14.90, 0.24 with v=0.53,-0.26 This is a particle at 14.30, 0.93 with v=0.26,-0.54 collided with a distance of  0.9136843308555544
# This is a particle at 11.87, 0.59 with v=0.65,0.28 This is a particle at 12.27, 0.20 with v=0.05,0.28 collided with a distance of  0.5553134277965275
# This is a particle at 0.88, 18.78 with v=-0.46,1.00 This is a particle at 0.69, 19.53 with v=0.41,0.10 collided with a distance of  0.7695388561860849
# This is a particle at 6.45, 17.53 with v=0.08,0.09 This is a particle at 5.55, 17.63 with v=0.51,0.12 collided with a distance of  0.9098570732485973
# This is a particle at 0.24, 16.40 with v=0.34,0.30 This is a particle at 0.51, 16.83 with v=-0.09,-0.22 collided with a distance of  0.515203312000953
# This is a particle at 11.94, 1.43 with v=0.34,0.58 This is a particle at 12.24, 2.37 with v=0.24,0.30 collided with a distance of  0.9854306105062062
# This is a particle at 1.04, 17.58 with v=0.27,0.34 This is a particle at 0.94, 18.57 with v=-0.19,-0.05 collided with a distance of  0.9922888618448015
# This is a particle at 15.96, 10.21 with v=0.17,-0.67 This is a particle at 15.09, 9.73 with v=0.20,0.21 collided with a distance of  0.9944444095932305

# %% [markdown]
# The following code is just for visualisation purposes.
#
# Plotting trajectory with Matplotlib:

# %%
for data_traj_j in data_traj:
    plt.plot(data_traj_j[0],data_traj_j[1],'-')
plt.xlabel('position x')
plt.ylabel('position y')

plt.grid()
plt.show()

# %% [markdown]
# **Animate trajectory:**

# %% [markdown]
# * Set up the figure, the axis, and the plot element we want to animate

# %%
fig, ax = plt.subplots()

ax.set_xlim((0, box[0]))
ax.set_ylim((0, box[1]))

plt.xlabel('position x')
plt.ylabel('position y')

# make the points in the plot the correct size according to the radius of the particles
# use ax.transData.transform to convert radius size from particle to markerSize from pyplot
desired_size_in_data_units = radius
data_to_points = ax.transData.transform((desired_size_in_data_units, 0)) - ax.transData.transform((0, 0))
marker_size_in_points = data_to_points[0]


dot, = ax.plot([], [], 'bo', ms=marker_size_in_points)


#ax.plot(5,5, 'bo', ms=marker_size_in_points)
# dont show the plot 
#plt.close()

# %%
# * initialization function: plot the background of each frame
def init():
    dot.set_data([], [])
    return (dot,)

# %%
# animation function. This is called sequentially
def animate(i):
    x = data_traj[:,0,i]
    y = data_traj[:,1,i]
    dot.set_data(x, y)
    return (dot,)

# %% [markdown]
# * call the animator. blit=True means only re-draw the parts that have changed.

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=steps, interval=60, blit=True)

# %%
HTML(anim.to_html5_video())

# uncomment if video should not be saved
anim.save('animation.mp4', writer='ffmpeg', fps=30)

# %% [markdown]
# ***Task III - analysis of the velocity distributions:***
#
# Finally the results from the above simulation can be analysed.

# %% [markdown]
# Analysis of the velocity distribution in x direction
# In order to plot a histogram the data saved in the data_traj has to be transformed into a list.

# %%
# format of data_traj:

list_for_histogramm = []
for i in range(steps):
    for j in range(number_of_particles):
        list_for_histogramm.append((data_traj)[j, 0, i])

plt.hist(list_for_histogramm,range=(0,box[0]),bins=10)
plt.xlabel('position x')
plt.ylabel('occupancy')
plt.show()

# %%
# histogram of the y positions

list_for_histogramm = []
for i in range(steps):
    for j in range(number_of_particles):
        list_for_histogramm.append((data_traj)[j, 1, i])

plt.hist(list_for_histogramm,range=(0,box[0]),bins=10)
plt.xlabel('position y')
plt.ylabel('occupancy')
plt.show()

# %%
# 2d plot of the position distribution

a = []
for i in range(steps):
    for j in range(number_of_particles):
        a.append((data_traj)[j, 0, i])
b = []
for i in range(steps):
    for j in range(number_of_particles):
        b.append((data_traj)[j, 1, i])
    

plt.hist2d(a, b, range=[[0,box[0]],[0,box[1]]], bins=10)
plt.xlabel('position x')
plt.ylabel('position y')
plt.colorbar().set_label('occupancy')
plt.show()

# %% [markdown]
# In the above plots it can be observed that whilst the simple histograms of x and y distribution show an evenly spread distribution, in 2D the box is not homogeniously sampled. Certain spots show a significantly higher occupancy than others. This is clearly a limitation.

# %%
# comparison of different iteration parts

# first 10%
first_10_percent = []
for i in range(np.int(0.1 *steps)):
    for j in range(number_of_particles):
        first_10_percent.append(data_traj[j,2,i])

# last 10%
last_10_percent = []
i_0 = np.int(0.9 * steps)-1
for i in range(np.int(0.1 * steps)):
    i = i+i_0
    
    for j in range(number_of_particles):
        last_10_percent.append(data_traj[j,2,i])
    i = i+1

plt.hist(first_10_percent,bins=10, label = 'first 10% iterations')
plt.hist(last_10_percent,bins=10, label = 'last 10% iterations', alpha=0.5)
plt.xlabel('velocity x')
plt.ylabel('occupancy')
plt.legend()
plt.show()

# %% [markdown]
# Analysis of the velocity distribution in the x direction

# %%
# histogram of the x velocity

list_for_histogram_x_velocities = []
for i in range(steps):
    for j in range(number_of_particles):
        list_for_histogram_x_velocities.append((data_traj)[j, 2, i])
    
plt.hist(list_for_histogram_x_velocities,bins=50)
plt.xlabel('velocity x')
plt.ylabel('occupancy')
plt.show()

# %%
# histogram of the y velocity

a = []
for i in range(steps):
    for j in range(number_of_particles):
        a.append((data_traj)[j, 3, i])
    
plt.hist(a,bins=50)
plt.xlabel('velocity y')
plt.ylabel('occupancy')
plt.show()

# %%
# Maxwell Boltzmann Distribution
def mwb_dist(vs, const):
    # const = kT / m
    return 4 * np.pi * (2 * np.pi * const)**(-3/2) * vs**2 * np.exp(-0.5 * vs**2 / const)

# %%
all_velocities = []
for i in range(steps):
    for j in range(number_of_particles):
        if i < data_traj.shape[0] and j < data_traj.shape[2]:
            velocity = np.sqrt((data_traj[i, 2, j])**2 + (data_traj[i, 3, j])**2)
            all_velocities.append(velocity)


plt.hist(all_velocities,bins=100)
plt.xlabel('velocity |v|')
plt.ylabel('occupancy')
plt.show()

# %% [markdown]
# **Interpretation:**
# * in the reduced data projection, the occupancy of each bin seems even and well-distributed
# * in the full dimensional projection, it can be seen easily that the box is **not** fully sampled, large undersampled patches present
# * *data dimensionality reduction always brings the danger of wrong projection!*

# %% [markdown]
# **Solution for improvements:**
# * enhance sampling by
#     * prolong the simulation
#     * increase the time step
# * *Caveat: all solutions come with problems like increased computational cost or sampling errors!*
